# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('Ecommerce Purchases')

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
len(ecom.columns)
# Out:
# 14

# %%
len(ecom.index)
# Out:
# 10000

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %%
# Out:
# 50.34730200000025

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom['Purchase Price'].max()
# Out:
# 99.989999999999995

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %%
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
gecom = ecom.groupby('Language')

# %%
gecom.count()
# Out:
#           Address   Lot  AM or PM  Browser Info  Company  Credit Card  \
# Language
# de           1155  1155      1155          1155     1155         1155
# el           1137  1137      1137          1137     1137         1137
# en           1098  1098      1098          1098     1098         1098
# es           1095  1095      1095          1095     1095         1095
# fr           1097  1097      1097          1097     1097         1097
# it           1086  1086      1086          1086     1086         1086
# pt           1118  1118      1118          1118     1118         1118
# ru           1155  1155      1155          1155     1155         1155
# zh           1059  1059      1059          1059     1059         1059
#
#           CC Exp Date  CC Security Code  CC Provider  Email   Job  IP Address  \
# Language
# de               1155              1155         1155   1155  1155        1155
# el               1137              1137         1137   1137  1137        1137
# en               1098              1098         1098   1098  1098        1098
# es               1095              1095         1095   1095  1095        1095
# fr               1097              1097         1097   1097  1097        1097
# it               1086              1086         1086   1086  1086        1086
# pt               1118              1118         1118   1118  1118        1118
# ru               1155              1155         1155   1155  1155        1155
# zh               1059              1059         1059   1059  1059        1059
#
#           Purchase Price
# Language
# de                  1155
# el                  1137
# en                  1098
# es                  1095
# fr                  1097
# it                  1086
# pt                  1118
# ru                  1155
# zh                  1059

# %%
ecom[ecom['Language']=='en'].count()
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %%
ecom['Language'].value_counts()
# Out:
# ru    1155
# de    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
# Out:
# Address             1098
# Lot                 1098
# AM or PM            1098
# Browser Info        1098
# Company             1098
# Credit Card         1098
# CC Exp Date         1098
# CC Security Code    1098
# CC Provider         1098
# Email               1098
# Job                 1098
# IP Address          1098
# Language            1098
# Purchase Price      1098
# dtype: int64

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
# 4        Brown, Watson and Andrews  6011456623207998       10/25
#
#    CC Security Code                  CC Provider  \
# 0               900                 JCB 16 digit
# 1               561                   Mastercard
# 2               699                 JCB 16 digit
# 3               384                     Discover
# 4               678  Diners Club / Carte Blanche
#
#                             Email                                     Job  \
# 0               pdunlap@yahoo.com  Scientist, product/process development
# 1              anthony41@reed.com                       Drilling engineer
# 2  amymiller@morales-harrison.com                Customer service manager
# 3     brent16@olson-robinson.info                       Drilling engineer
# 4     christopherwright@gmail.com                             Fine artist
#
#         IP Address Language  Purchase Price
# 0  149.146.147.205       el           98.14
# 1     15.160.41.51       fr           70.73
# 2   132.207.160.22       de            0.95
# 3     30.250.74.19       es           78.04
# 4     24.140.33.94       es           77.82

# %%
ecom[ecom['Job']=='Lawyer'].count()
# Out:
# Address             30
# Lot                 30
# AM or PM            30
# Browser Info        30
# Company             30
# Credit Card         30
# CC Exp Date         30
# CC Security Code    30
# CC Provider         30
# Email               30
# Job                 30
# IP Address          30
# Language            30
# Purchase Price      30
# dtype: int64

# %%
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# 12      733 Heather Rest Apt. 670\nBoltonport, UT 78662  69 DO       AM
# 13    118 Melton Via Suite 681\nAlexanderbury, FL 32104  36 bu       PM
# 14    8774 Jason Keys Suite 427\nEast Scottborough, ...  70 zH       AM
# 15       31730 Chelsea Crest\nBlakemouth, CT 90395-0620  41 Cj       PM
# 16    5283 Thomas Trafficway Suite 343\nEast Brittne...  31 ho       AM
# 17    950 Jacqueline Village Apt. 592\nPort Kimberly...  23 Rh       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 20        7383 George Village\nLake Jamesview, CO 79828  23 dk       PM
# 21    282 Miller Valleys Suite 404\nWilkinsonbury, M...  24 RZ       AM
# 22     625 Laura Summit Suite 112\nShortmouth, AK 97156  45 oa       PM
# 23    25292 Shepherd Trail Apt. 798\nRussellmouth, S...  31 pS       PM
# 24                Unit 3046 Box 3197\nDPO AE 61496-4172  62 Ac       AM
# 25    80797 Ryan Trail Apt. 752\nAaronhaven, MI 0622...  66 SO       PM
# 26          5334 Sheppard Fort\nNorth Kirsten, ND 71170  40 ND       AM
# 27           5015 Smith Harbors\nSouth Ashley, OK 81283  34 JQ       PM
# 28    50533 Cooper Cliffs\nNorth Jonathanberg, MD 20482  17 kP       PM
# 29    30755 Joshua Plaza Apt. 567\nWest Susanton, FM...  93 OP       PM
# ...                                                 ...    ...      ...
# 6145  261 Samantha Squares Apt. 186\nJustinton, KS 5...  96 zZ       PM
# 6171  6966 Jose Summit Suite 123\nMargaretville, UT ...  21 nh       AM
# 6215      725 Renee Expressway\nNew Sara, FM 71252-4007  11 CX       PM
# 6309              PSC 6716, Box 4921\nAPO AA 13379-1269  82 IS       PM
# 6340            57504 Carlos Brook\nGarciaton, MP 25831  30 py       AM
# 6349          011 Debra Mountain\nKristamouth, NH 36271  21 yB       PM
# 6411      431 William Street\nRamseyland, UT 25019-0009  56 FQ       AM
# 6425  273 Zachary Field Suite 326\nSmithhaven, AS 54654  14 Li       AM
# 6430    01573 Kristin Drive\nRodriguezchester, NH 13486  64 dI       PM
# 6461  06086 Turner Stream Suite 632\nSouth Jessica, ...  13 VU       AM
# 6489     752 Garcia Shore\nWilsonchester, TN 83038-1830  65 sM       AM
# 6499  3645 Susan Bridge Apt. 383\nKerrymouth, PA 451...  49 xV       PM
# 6532                    USNS Vasquez\nFPO AP 50722-9795  68 Xd       PM
# 6680              515 Dana Mountain\nNew Adam, MN 71973  28 oV       AM
# 6717  85152 Rebekah Pine\nSouth Oscarhaven, MA 23667...  93 vH       PM
# 6816  227 Donna Creek Suite 887\nBrandichester, CO 8...  96 Sv       AM
# 6938  9676 Jessica Crescent Apt. 290\nNorth Mauricet...  58 kt       AM
# 7154  98913 Jeremiah Spur Apt. 633\nVargasville, HI ...  51 yf       PM
# 7160  942 Jane Park Suite 392\nPort Melissastad, AK ...  37 Gf       PM
# 7163  5133 Conley Dam Apt. 995\nSouth Angelastad, AZ...  77 fG       PM
# 7165                002 Lisa Camp\nWest Bryan, ID 63947  87 GU       AM
# 7241     868 Hernandez Viaduct\nWest Josebury, OH 50882  78 TN       PM
# 7338  89174 Cody Station Suite 737\nEast Heatherbury...  37 ql       PM
# 7342  1579 Robert Turnpike Apt. 054\nSouth Deborahvi...  28 th       PM
# 7374  42410 Henry Land Apt. 796\nLake Marisa, PW 947...  31 aZ       PM
# 7470         797 Ruiz Fords\nCarlsonstad, HI 15825-2195  70 fh       PM
# 7639              Unit 2807 Box 1152\nDPO AE 90364-7161  69 GO       AM
# 7806              3241 Pineda Run\nCastroberg, ME 87855  92 nI       PM
# 8470    36417 David Lakes\nNorth Amybury, WY 77258-7625  76 Xl       AM
# 9649  801 Mitchell Extension Suite 596\nWest Adammou...  83 WA       AM
#
#                                            Browser Info  \
# 0     Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1     Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2     Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4     Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
# 5     Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_8_5...
# 6     Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# 7     Mozilla/5.0 (X11; Linux i686) AppleWebKit/5350...
# 8     Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9     Mozilla/5.0 (X11; Linux i686; rv:1.9.7.20) Gec...
# 10    Mozilla/5.0 (iPod; U; CPU iPhone OS 4_1 like M...
# 11    Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 12    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_5_3 ...
# 13    Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_8...
# 14    Mozilla/5.0 (Windows 98; it-IT; rv:1.9.2.20) G...
# 15    Opera/8.95.(Windows NT 5.0; en-US) Presto/2.9....
# 16    Opera/9.73.(Windows NT 6.2; sl-SI) Presto/2.9....
# 17    Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 18    Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 19    Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# 20    Mozilla/5.0 (Windows; U; Windows NT 4.0) Apple...
# 21    Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...
# 22    Mozilla/5.0 (Windows 95) AppleWebKit/5342 (KHT...
# 23    Mozilla/5.0 (compatible; MSIE 5.0; Windows 98;...
# 24    Mozilla/5.0 (compatible; MSIE 6.0; Windows CE;...
# 25    Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_7_1...
# 26    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_3)...
# 27    Opera/9.75.(Windows NT 6.0; en-US) Presto/2.9....
# 28    Mozilla/5.0 (Windows; U; Windows NT 6.1) Apple...
# 29    Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_6_7...
# ...                                                 ...
# 6145  Opera/8.70.(X11; Linux i686; sl-SI) Presto/2.9...
# 6171  Opera/9.68.(X11; Linux x86_64; sl-SI) Presto/2...
# 6215  Opera/9.22.(X11; Linux x86_64; en-US) Presto/2...
# 6309  Mozilla/5.0 (Windows NT 6.2) AppleWebKit/5342 ...
# 6340  Mozilla/5.0 (Windows CE) AppleWebKit/5341 (KHT...
# 6349  Mozilla/5.0 (Windows NT 6.0; it-IT; rv:1.9.0.2...
# 6411  Mozilla/5.0 (Windows 98; Win 9x 4.90) AppleWeb...
# 6425  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6...
# 6430  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 6461  Mozilla/5.0 (Windows; U; Windows NT 6.2) Apple...
# 6489  Mozilla/5.0 (compatible; MSIE 7.0; Windows NT ...
# 6499  Mozilla/5.0 (compatible; MSIE 6.0; Windows NT ...
# 6532  Mozilla/5.0 (Windows; U; Windows NT 6.0) Apple...
# 6680  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_1 like M...
# 6717  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 6816  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 6938  Opera/9.93.(Windows 98; Win 9x 4.90; it-IT) Pr...
# 7154  Mozilla/5.0 (compatible; MSIE 6.0; Windows 95;...
# 7160  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_9;...
# 7163  Opera/8.23.(Windows NT 5.1; en-US) Presto/2.9....
# 7165  Mozilla/5.0 (Windows NT 6.0; en-US; rv:1.9.0.2...
# 7241  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...
# 7338  Mozilla/5.0 (iPod; U; CPU iPhone OS 4_2 like M...
# 7342  Mozilla/5.0 (X11; Linux x86_64; rv:1.9.7.20) G...
# 7374  Mozilla/5.0 (Windows NT 5.1; it-IT; rv:1.9.1.2...
# 7470  Mozilla/5.0 (iPod; U; CPU iPhone OS 3_3 like M...
# 7639  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_6...
# 7806  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_6)...
# 8470  Opera/9.19.(Windows NT 4.0; sl-SI) Presto/2.9....
# 9649  Mozilla/5.0 (Windows; U; Windows NT 5.2) Apple...
#
#                                Company       Credit Card CC Exp Date  \
# 0                      Martinez-Herman  6011929061123406       02/20
# 1      Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2           Simpson, Williams and Pham      675957666125       08/19
# 3      Williams, Marshall and Buchanan  6011578504430710       02/24
# 4            Brown, Watson and Andrews  6011456623207998       10/25
# 5                       Silva-Anderson    30246185196287       07/25
# 6                      Gibson and Sons  6011398782655569       07/24
# 7                     Marshall-Collins      561252141909       06/25
# 8                    Galloway and Sons   180041795790001       04/24
# 9         Rivera, Buchanan and Ramirez     4396283918371       01/17
# 10    Strickland, Michael and Gonzales   180036417827355       02/17
# 11                          Kim-Oliver   869975209012056       06/26
# 12                        Moore-Martin  5115990487067905       05/26
# 13                          Keller PLC  4603635169938574       01/25
# 14            Leach, Howe and Ferguson   869967499275071       09/22
# 15                       Garcia-Steele   180069437020404       04/25
# 16     Stanton, Villanueva and Swanson      676121145525       06/22
# 17       Fernandez, Melton and Gilbert  3337515540944084       01/26
# 18              Beard, Abbott and Pena  6011350184276270       12/22
# 19                     Turner-Mckinney      676343504830       02/20
# 20          Santana, Montes and Pierce  6011833038852776       03/22
# 21                        Guzman-Reese  5491255326230898       03/25
# 22                         Burnett Ltd  3158663456056588       07/22
# 23                            Cruz Inc      502010078983       02/23
# 24                          Morris PLC  4749728852401144       07/18
# 25                     Saunders-Mendez   869938033091779       05/19
# 26         Stephens, Johnson and Combs       60488441233       03/19
# 27            Levine, Shaw and Jenkins   869948145612941       12/16
# 28                            Reed Inc   180026477662982       11/24
# 29                         Goodwin Ltd  4170734785397597       07/22
# ...                                ...               ...         ...
# 6145                    Cummings-Burns  3528396483230834       01/26
# 6171                  Mcdaniel-Rosales  4341562496840488       11/23
# 6215       Mcguire, Beard and Gonzales   375148430928089       03/20
# 6309                        Sims Group     4174245439970       10/18
# 6340                        Adkins PLC   210018847064662       06/26
# 6349                       Roberts Inc  4590806033994847       04/19
# 6411                         Lewis Ltd  4024966261310573       10/19
# 6425           Tate, Higgins and Jones  6011485427124133       08/20
# 6430                      Adams-Conner   210024858859107       10/20
# 6461                     Kirby-Johnson  4821511543950625       12/18
# 6489                    Bailey-Francis  6011746539509713       02/18
# 6499                  Rodriguez-Martin  3158724607423042       07/24
# 6532          Bryant, Lewis and Newman   869923600945706       07/21
# 6680         Reed, Conner and Richards   869961043627325       05/17
# 6717                       Myers-Munoz  5348112622790924       01/23
# 6816                        Oneill LLC  4566004893217968       05/21
# 6938           Payne, Lopez and Wilcox  3088638038552168       11/22
# 7154                       Lucas Group     4228892845671       09/22
# 7160          Barr, Roberts and Ramsey      630489435416       10/18
# 7163                       Rivera-Lutz  5180773449460933       10/21
# 7165                   Gentry-Hatfield     4141275945713       04/19
# 7241                      Hansen-Salas  3528303798377714       10/16
# 7338         Suarez, Bishop and Harris  5503782148472495       11/18
# 7342                        Reeves Inc  4534961364552075       02/22
# 7374                   Wilson and Sons  3112243313316239       10/23
# 7470                     Lewis-Johnson   210041032357949       05/20
# 7639                         Price Ltd  3337549391700444       09/21
# 7806                      Nelson-Lyons   342876940798788       09/25
# 8470       Avila, Carter and Hendricks      676136387146       04/23
# 9649                    Marshall-Quinn  5386771303740202       10/18
#
#       CC Security Code                  CC Provider  \
# 0                  900                 JCB 16 digit
# 1                  561                   Mastercard
# 2                  699                 JCB 16 digit
# 3                  384                     Discover
# 4                  678  Diners Club / Carte Blanche
# 5                 7169                     Discover
# 6                  714                VISA 16 digit
# 7                  256                VISA 13 digit
# 8                  899                 JCB 16 digit
# 9                  931             American Express
# 10                 754                      Voyager
# 11                9717                 JCB 15 digit
# 12                 119                VISA 16 digit
# 13                 557                VISA 16 digit
# 14                 427                VISA 16 digit
# 15                 404  Diners Club / Carte Blanche
# 16                 285  Diners Club / Carte Blanche
# 17                 771             American Express
# 18                 767                   Mastercard
# 19                 440                VISA 16 digit
# 20                 740                      Maestro
# 21                 506                 JCB 16 digit
# 22                 508                     Discover
# 23                  60                VISA 13 digit
# 24                  11                 JCB 15 digit
# 25                 901                      Voyager
# 26                  70                VISA 13 digit
# 27                 310  Diners Club / Carte Blanche
# 28                  16                 JCB 15 digit
# 29                 319                      Maestro
# ...                ...                          ...
# 6145              4691                VISA 16 digit
# 6171               270             American Express
# 6215               118                VISA 13 digit
# 6309               726                      Maestro
# 6340               521                 JCB 15 digit
# 6349                18             American Express
# 6411              9538                      Maestro
# 6425               110                 JCB 15 digit
# 6430               159                VISA 16 digit
# 6461               621                 JCB 16 digit
# 6489                19                      Voyager
# 6499               992                   Mastercard
# 6532               654                 JCB 15 digit
# 6680                79                VISA 16 digit
# 6717               451                 JCB 16 digit
# 6816                56                     Discover
# 6938               505                      Voyager
# 7154               595                      Voyager
# 7160               892                VISA 16 digit
# 7163               499                 JCB 16 digit
# 7165               437  Diners Club / Carte Blanche
# 7241               695                 JCB 16 digit
# 7338               156                      Maestro
# 7342               497                     Discover
# 7374               172                      Maestro
# 7470               438                   Mastercard
# 7639               979                VISA 16 digit
# 7806               965                 JCB 15 digit
# 8470               408                 JCB 16 digit
# 9649               163                 JCB 16 digit
#
#                                    Email  \
# 0                      pdunlap@yahoo.com
# 1                     anthony41@reed.com
# 2         amymiller@morales-harrison.com
# 3            brent16@olson-robinson.info
# 4            christopherwright@gmail.com
# 5                      ynguyen@gmail.com
# 6                     olivia04@yahoo.com
# 7                   phillip48@parks.info
# 8                   kdavis@rasmussen.com
# 9               qcoleman@hunt-huerta.com
# 10                  ustewart@hotmail.com
# 11              johnnymiller@coleman.com
# 12                     tholt@hotmail.com
# 13                   caitlin57@yahoo.com
# 14                      aburns@yahoo.com
# 15                    amanda39@yahoo.com
# 16           griffincatherine@wilson.com
# 17                stacymitchell@hall.com
# 18                    hannah63@yahoo.com
# 19                  ruiznicole@gmail.com
# 20                zstephenson@smith.info
# 21                    rsmith@hotmail.com
# 22             chambersmichael@gmail.com
# 23           ltaylor@gardner-meadows.com
# 24                     james07@yahoo.com
# 25                  madison41@mooney.com
# 26                      mlogan@gmail.com
# 27                 michael35@hotmail.com
# 28                 khandeborah@yahoo.com
# 29                  stonekaren@yahoo.com
# ...                                  ...
# 6145           kimberlymills@hotmail.com
# 6171               kellyamanda@gmail.com
# 6215         barneschristina@buckley.com
# 6309             ortizmitchell@yahoo.com
# 6340          samuelyoder@valenzuela.org
# 6349                 douglas47@yahoo.com
# 6411            cantuheather@hotmail.com
# 6425                 brandon66@yahoo.com
# 6430                    ruth94@gmail.com
# 6461                 richard69@yahoo.com
# 6489        middletonmichele@hotmail.com
# 6499                jamesyoung@yahoo.com
# 6532                smcdaniel@powers.com
# 6680                  rodney16@yahoo.com
# 6717                  lhaley@hotmail.com
# 6816             kaufmandonald@jones.biz
# 6938                    timothy50@le.com
# 7154             torreslindsey@yahoo.com
# 7160                  mdaniels@yahoo.com
# 7163               hinesjudith@yahoo.com
# 7165         veronicafarrell@padilla.com
# 7241                 wmartinez@yahoo.com
# 7338             daniel67@montgomery.com
# 7342         nguyengabriella@bailey.info
# 7374              baileymark@hotmail.com
# 7470                    mlewis@gmail.com
# 7639  johnsonmaria@jackson-hernandez.biz
# 7806           ericaleblanc@gonzales.com
# 8470              charlesjeremy@hill.com
# 9649           richard86@quinn-brown.com
#
#                                          Job       IP Address Language  \
# 0     Scientist, product/process development  149.146.147.205       el
# 1                          Drilling engineer     15.160.41.51       fr
# 2                   Customer service manager   132.207.160.22       de
# 3                          Drilling engineer     30.250.74.19       es
# 4                                Fine artist     24.140.33.94       es
# 5                          Fish farm manager    55.96.152.147       ru
# 6                                     Dancer   127.252.144.18       de
# 7                            Event organiser   224.247.97.150       pt
# 8                          Financial manager  146.234.201.229       ru
# 9                         Forensic scientist    236.198.199.8       zh
# 10             Development worker, community       26.59.93.1       el
# 11                   Diagnostic radiographer   128.222.40.234       en
# 12                        Surveyor, quantity   236.71.234.240       en
# 13      Accountant, chartered public finance     84.212.92.11       it
# 14                             Acupuncturist      50.25.148.1       de
# 15                            Retail manager    53.176.235.33       el
# 16                            Therapist, art     8.145.170.52       de
# 17                       Designer, jewellery    223.25.125.61       el
# 18                              Photographer   73.250.176.201       el
# 19                Designer, interior/spatial   25.105.209.214       fr
# 20                  Public relations officer    250.71.54.180       de
# 21                   Presenter, broadcasting    125.58.66.253       it
# 22                            Retail manager    65.106.61.141       en
# 23                        Field seismologist   25.193.145.116       ru
# 24                                  Musician   21.113.231.220       es
# 25          Training and development officer    67.26.186.226       de
# 26                         Barrister's clerk   61.197.134.185       en
# 27                           Careers adviser   177.220.131.93       es
# 28       Scientist, research (life sciences)  142.131.235.225       es
# 29                         Recycling officer  218.189.145.248       it
# ...                                      ...              ...      ...
# 6145                             Adult nurse     246.2.177.56       zh
# 6171                          Teacher, music     92.25.74.199       fr
# 6215                    Intelligence analyst    79.173.17.142       pt
# 6309                      Investment analyst  191.231.190.227       ru
# 6340                  Politician's assistant   209.113.51.136       de
# 6349                          Police officer   100.41.238.193       en
# 6411                       Medical secretary   234.71.202.194       ru
# 6425                    Public house manager     4.133.124.20       fr
# 6430                        Technical brewer       34.59.6.59       it
# 6461     Exhibitions officer, museum/gallery      242.97.4.14       de
# 6489     Exhibitions officer, museum/gallery   207.22.230.194       es
# 6499                      Production manager  244.254.195.121       pt
# 6532                          Teacher, music     191.80.29.34       pt
# 6680                              Bookseller  202.180.186.232       en
# 6717                           Airline pilot     220.31.171.4       fr
# 6816             Information systems manager    189.22.92.226       it
# 6938   Senior tax professional/tax inspector    38.248.43.148       es
# 7154                      Investment analyst    87.59.102.214       pt
# 7160             Information systems manager  175.198.144.166       ru
# 7163         Administrator, local government   55.107.153.131       pt
# 7165                 Therapist, occupational     50.155.16.50       el
# 7241                         Music therapist     51.218.178.7       fr
# 7338                        Technical brewer   218.222.89.161       en
# 7342              Nurse, learning disability      86.44.45.55       de
# 7374          Investment banker, operational  201.247.251.100       ru
# 7470   Senior tax professional/tax inspector   215.164.151.30       it
# 7639                         Learning mentor     67.28.45.167       el
# 7806         Administrator, local government     250.1.202.68       es
# 8470                      Investment analyst   205.158.20.114       en
# 9649             Information systems manager     67.188.45.35       es
#
#       Purchase Price
# 0              98.14
# 1              70.73
# 2               0.95
# 3              78.04
# 4              77.82
# 5              25.15
# 6              88.56
# 7              44.25
# 8              59.54
# 9              95.63
# 10             96.89
# 11             19.26
# 12             39.65
# 13              8.93
# 14             24.18
# 15             71.78
# 16             84.44
# 17             58.68
# 18             70.15
# 19             58.39
# 20             30.33
# 21             90.93
# 22             33.62
# 23             97.97
# 24             85.31
# 25              6.25
# 26             17.75
# 27             39.40
# 28             70.75
# 29             82.16
# ...              ...
# 6145           35.05
# 6171           91.29
# 6215           58.10
# 6309           87.72
# 6340           55.54
# 6349           68.02
# 6411           17.34
# 6425           44.64
# 6430           27.98
# 6461           71.33
# 6489           31.56
# 6499           60.79
# 6532           69.63
# 6680           99.18
# 6717           21.84
# 6816           85.79
# 6938           77.71
# 7154           66.40
# 7160            7.06
# 7163           27.16
# 7165           97.18
# 7241           11.18
# 7338           74.35
# 7342           94.15
# 7374           50.74
# 7470            0.67
# 7639           89.63
# 7806           65.43
# 8470           18.24
# 9649           90.74
#
# [3115 rows x 14 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 470 to 9979
# Data columns (total 14 columns):
# Address             30 non-null object
# Lot                 30 non-null object
# AM or PM            30 non-null object
# Browser Info        30 non-null object
# Company             30 non-null object
# Credit Card         30 non-null int64
# CC Exp Date         30 non-null object
# CC Security Code    30 non-null int64
# CC Provider         30 non-null object
# Email               30 non-null object
# Job                 30 non-null object
# IP Address          30 non-null object
# Language            30 non-null object
# Purchase Price      30 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.5+ KB

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Designer, jewellery                  27
# Research officer, political party    27
# Name: Job, dtype: int64

# %%
ecom[Lot]=='90 WT'

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
ecom[ecom['Credit Card']==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %%
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
ecom[(ecom['CC Provider']=='American Express') & (ecom['Purchase Price']>95)].count()
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %%
# Out:
# Address             39
# Lot                 39
# AM or PM            39
# Browser Info        39
# Company             39
# Credit Card         39
# CC Exp Date         39
# CC Security Code    39
# CC Provider         39
# Email               39
# Job                 39
# IP Address          39
# Language            39
# Purchase Price      39
# dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
ecom[ecom['CC Exp Date'].apply(lambda x: x[3:]=='25')].count()
# Out:
# Address             1033
# Lot                 1033
# AM or PM            1033
# Browser Info        1033
# Company             1033
# Credit Card         1033
# CC Exp Date         1033
# CC Security Code    1033
# CC Provider         1033
# Email               1033
# Job                 1033
# IP Address          1033
# Language            1033
# Purchase Price      1033
# dtype: int64

# %%
joe = 'yujoyuikjuk'

# %%
joe[2]
# Out:
# 'j'

# %%
# Out:
# 1033

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %%
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64

# %% [markdown]
# # Great Job!
